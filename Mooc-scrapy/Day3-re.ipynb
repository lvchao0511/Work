# %% [markdown]
# ## 淘宝商品比价
# 由于Taobao的反爬虫机制，其中的Cookie每隔一段时间就要手动更换。

# %%
import requests
import re

def getHTMLText(url):
    payload={}
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.61 Safari/537.36 Edg/90.0.818.36', 
        'Cookie': 'cna=V56oFTpKnXcCAcqoo/7ER9SV; hng=CN%7Czh-CN%7CCNY%7C156; thw=cn; t=fe71297e0624ac68095eeeaaf1edcdbf; xlly_s=1; sgcookie=E100YxyuG2C7Xh3tsj9gpCNyNd4FdUclIM%2FuiLRlHQxZ8dMM%2FjNJK4oewtQEdEVQp2ezv9A7iIjr6OtzGE%2FvTmySXA%3D%3D; uc3=lg2=W5iHLLyFOGW7aA%3D%3D&nk2=AHY3eFaxZ%2FLnyww%3D&vt3=F8dCuwpnksKLkC%2Bn6ws%3D&id2=UoW0EP9dNI0n; lgc=clumsylemon; uc4=id4=0%40UO2jb5T9NuUoF9ABhR3JEJlGx50%3D&nk4=0%40AhhKlqQJsCMzZJBI5VC%2B0kZpjI%2Fisg%3D%3D; tracknick=clumsylemon; _cc_=VFC%2FuZ9ajQ%3D%3D; enc=v7pFKB0OtBv6RdM2%2FtXl98kcIh64MaAdFnexDvdAp6XHq1c6lHupm2BikI6nyGK7%2F2GTWNtjUinXz1CIIS4KJQ%3D%3D; mt=ci=29_1; _uab_collina=161858074180346296794251; _m_h5_tk=05a31124615dda185324951aaf7161eb_1618628636143; _m_h5_tk_enc=39e1b82428911efd793600bf2c385c4d; uc1=cookie14=Uoe1iua7Luk6jw%3D%3D; cookie2=14d148c935b7e7df474ccc9e1da3244c; _tb_token_=78343d1dee373; JSESSIONID=97A1F7BB24428004747AC22660A33F3A; alitrackid=www.taobao.com; lastalitrackid=www.taobao.com; l=eBN4zbwRQ03JpZF3BOfwlurza77O_IRxluPzaNbMiOCP9Q5H5fJPW6aaF-LMCnhVh6XpJ3PnLMC0BeYBqsqBfdW22j-la9kmn; isg=BFdXedVu-9TafUHw9Xd29a5n5suhnCv-NyEkAqmEbCaN2HcasG3gThW-O3hGTgN2; tfstk=ceUCBK4_qpvC82jy8W1wzCjG06uPZgss6MMaOoi_mibRhDPCidLqhfR3qdiAZf1..'
        }

    try:
        r = requests.get(url, timeout = 30, headers = headers, data = payload)
        r.raise_for_status()
        r.encoding = r.apparent_encoding
        return r.text
    except:
        return ""

def parsePage(ilt, html):
    print("")

def printGoodsList(ilt):
    print("")

def main():
    goods = '书包'
    depth = 2
    start_url = 'https://s.taobao.com/search?q=' + goods
    info_list = []
    for i in range(depth):
        try:
            url = start_url + '&s=' + '{}'.format(44*i)
            html = getHTMLText(url)
            print(html)
            parsePage(info_list, html)
        except:
            continue
    printGoodsList(info_list)

main()
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="renderer" content="webkit">
#     <meta name="data-spm" content="a230r">
#     <link rel="dns-prefetch" href="//g.alicdn.com">
#     <link rel="dns-prefetch" href="//assets.alicdn.com">
#     <link rel="dns-prefetch" href="//img.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search1.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search2.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search3.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search4.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms01.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms02.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms03.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms04.alicdn.com">
#     <link rel="shortcut icon" href="//www.taobao.com/favicon.ico">
# ...
